# %% [markdown]
# # Generic Trend Model

# %% [markdown]
# This notebook will focus on developing a simple trend following model based originally on *Tail Protection for Long Investors: Trend Convexity at Work*

# %% [markdown]
# # Packages

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import statsmodels.api as sm
from   statsmodels.regression.rolling import RollingOLS

# %% [markdown]
# # Collecting Data

# %%
path   = r"C:\Users\Diego\Documents\GitHub\TrendSystem\data\FuturesPX.parquet"
df_fut = (pd.read_parquet(
    path = path, engine = "pyarrow").
    rename(columns = {"ticker": "security"}).
    assign(ticker = lambda x: x.security.str.split("1").str[0].str.strip()))

# %%
path         = r"C:\Users\Diego\Documents\GitHub\TrendSystem\data\TickerGuide.xlsx"
good_tickers = (pd.read_excel(
    io = path, sheet_name = "fut_guide").
    rename(columns = {"Root Contract": "tmp"}).
    assign(tmp = lambda x: x.tmp.str.strip()).
    tmp.
    drop_duplicates().
    sort_values().
    to_list())

# %%
df_wider_px = (df_fut.query(
    "ticker == @good_tickers").
    pivot(index = "date", columns = "ticker", values = "adj_val"))

# %% [markdown]
# # Getting Benchmark Trend Data and Generating Generic Trend Signal

# %%
path     = r"C:\Users\Diego\Desktop\WeekyNotebooks\20260422AprilDataCollect (passed)\TrendIndices.parquet"
df_trend = (pd.read_parquet(
    path = path, engine = "pyarrow").
    assign(
        date     = lambda x: pd.to_datetime(x.date).dt.date,
        security = lambda x: x.security.str.split(" ").str[0]).
    pivot(index = "date", columns = "security", values = "PX_LAST").
    pct_change()
    [["NEIXCTAT"]])

# %%
df_signal = (df_wider_px.diff().apply(
    lambda x: x / x.ewm(span = 10, adjust = False).std()).
    apply(lambda x: x.ewm(span = 100, adjust = False).mean()))

# %% [markdown]
# # Case 1: Generic Model

# %%
df_signal_rtn = (df_wider_px.pct_change() * np.sign(df_signal.shift()))
df_vol_rtn    = (df_signal_rtn.apply(lambda x: x * (0.2 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))))

# %%
df_gen = (df_vol_rtn.apply(
    lambda x: np.where(np.abs(x) >= 12, np.nan, x)).
    mean(axis = 1).
    to_frame(name = "Generic TF").
    dropna())

# %%
df_generic_compare = (df_trend.merge(
    right = df_gen, how = "inner", on = ["date"]))

# %%
(df_generic_compare.
    apply(lambda x: np.cumprod(1 + x)).
    plot(
        figsize = (8,5),
        logy    = True,
        ylabel  = "Cuml. Ret. Log-Scaled",
        title   = "Comparing Generic 100d EWMA Trend vs. Soc Gen TF\nFrom {} to {}".format(
            df_generic_compare.index.min(),
            df_generic_compare.index.max())))

plt.show()

# %%
correlation = df_generic_compare.corr()["Generic TF"].iloc[0]
(df_generic_compare.agg(
    lambda x: x.mean() / x.std() * np.sqrt(252)).
    to_frame(name = "").
    T.
    assign(Correlation = correlation))
# Out:
#   NEIXCTAT  Generic TF  Correlation
#   0.491553    0.748665     0.650923

# %% [markdown]
# # Case 2: Generic OLS Residuals

# %%
df_signal = (df_wider_px.diff().apply(
    lambda x: x / x.ewm(span = 10, adjust = False).std()).
    apply(lambda x: x.ewm(span = 100, adjust = False).mean()).
    shift().
    reset_index().
    melt(id_vars = "date", value_name = "lag_signal").
    dropna())

# %%
df_rtn = (df_wider_px.pct_change().apply(
    lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    reset_index().
    melt(id_vars = "date", value_name = "vol_rtn").
    dropna())

# %%
def _get_ols(df: pd.DataFrame, window: int = 30) -> pd.DataFrame: 

    df_is = (sm.OLS(
        endog = df.vol_rtn,
        exog  = sm.add_constant(df.lag_signal)).
        fit().
        fittedvalues.
        to_frame(name = "is_pred"))

    oos_model = (RollingOLS(
        endog     = df.vol_rtn,
        exog      = sm.add_constant(df.lag_signal),
        expanding = True).
        fit())

    df_out = (oos_model.params.rename(
        columns = {"lag_signal": "beta"}).
        shift().
        merge(right = df, how = "inner", on = ["date"]).
        assign(os_pred = lambda x: (x.beta * x.lag_signal) + x.const).
        merge(right = df_is, how = "inner", on = ["date"]))

df_ols = (df_signal.merge(
    right = df_rtn, how = "inner", on = ["date", "ticker"]).
    set_index("date").
    query("ticker == ticker.min()").
    groupby("ticker").
    apply(_get_ols))
# Out:
# C:\Users\Diego\anaconda3\Lib\site-packages\statsmodels\regression\rolling.py:255: RuntimeWarning: divide by zero encountered in scalar divide
#   s2 = ssr / (nobs - tot_params)
#                const      beta  lag_signal   vol_rtn   os_pred   is_pred
# date
# 2000-01-06       NaN       NaN    0.391860 -0.003842       NaN  0.000117
# 2000-01-07       NaN       NaN    0.371454  0.000569       NaN  0.000113
# 2000-01-10  0.080853 -0.216134    0.366043  0.001261  0.001738  0.000112
# 2000-01-11  0.075649 -0.202732    0.363321  0.002421  0.001992  0.000112
# 2000-01-12  0.078909 -0.211182    0.365222  0.000000  0.001781  0.000112
# ...              ...       ...         ...       ...       ...       ...
# 2026-06-03  0.000055  0.000175    0.076859 -0.007992  0.000068  0.000064
# 2026-06-04  0.000054  0.000171    0.045433  0.001100  0.000061  0.000059
# 2026-06-05  0.000054  0.000171    0.048908 -0.014949  0.000062  0.000059
# 2026-06-08  0.000052  0.000167    0.006290  0.000165  0.000053  0.000052
# 2026-06-09  0.000052  0.000167    0.006648 -0.002736  0.000053  0.000052
#
# [6516 rows x 6 columns]

# %%
df_fut_rtn = (df_wider_px.pct_change().reset_index().melt(
    id_vars = "date", value_name = "fut_rtn").
    dropna())

# %%
df_long_only = (df_fut_rtn.pivot(
    index = "date", columns = "ticker", values = "fut_rtn").
    apply(lambda x: x * (0.1 / (x.ewm(span = 100, adjust = False).std() * np.sqrt(252)))).
    mean(axis = 1).
    to_frame(name = "long_only"))

# %%
df_ols_port = (df_ols.merge(
    right = df_fut_rtn, how = "inner", on = ["date", "ticker"]).
    assign(signal_rtn = lambda x: np.sign(x.pred) * x.fut_rtn).
    pivot(index = "date", columns = "ticker", values = "signal_rtn").
    apply(lambda x: x * (0.2 / (x.ewm(span = 100, adjust = False).std().shift() * np.sqrt(252)))).
    apply(lambda x: np.where(np.abs(x) >= 25, np.nan, x)).
    mean(axis = 1).
    to_frame(name = "ols_pred"))

# %%
(df_ols_port.merge(
    right = df_long_only, how = "inner", on = ["date"]).
    apply(lambda x: np.cumprod(1 + x)).
    plot(logy = True))
# Out:
# <Axes: xlabel='date'>

# %%
(df_ols_port.merge(
    right = df_long_only, how = "inner", on = ["date"]).
    agg(lambda x: x.mean() / x.std() * np.sqrt(252)).
    to_frame(name = "sharpe"))
# Out:
#              sharpe
# ols_pred   0.761692
# long_only  0.376299

# %% [markdown]
# # Generic Optimized Deciles

# %%
def _get_decile(df: pd.DataFrame, q: int = 10) -> pd.DataFrame: 

    display(df.assign(
        decile ))
    
(df_signal.set_index(
    "date").
    query("ticker == ticker.min()").
    groupby("ticker").
    apply(_get_decile))
# Out:
#             lag_signal
# date
# 2000-01-06    0.391860
# 2000-01-07    0.371454
# 2000-01-10    0.366043
# 2000-01-11    0.363321
# 2000-01-12    0.365222
# ...                ...
# 2026-06-03    0.076859
# 2026-06-04    0.045433
# 2026-06-05    0.048908
# 2026-06-08    0.006290
# 2026-06-09    0.006648
#
# [6876 rows x 1 columns]
# Empty DataFrame
# Columns: [lag_signal]
# Index: []
