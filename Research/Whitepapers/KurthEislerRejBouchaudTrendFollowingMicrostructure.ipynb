# %% [markdown]
# # Is Trend Still Your Friend? A Microstructural Account of the Demise of Short-Term Trend-Following

# %%
import pandas as pd

path = r"A:\2026BlpAdHocData\Combined\Futures\Volume1.parquet"
(pd.read_parquet(path = path, engine = 'pyarrow').field.drop_duplicates())
# Out:
# 0    FUT_AGGTE_OPEN_INT
# 2             PX_VOLUME
# 3              OPEN_INT
# 5             PX_SETTLE
# Name: field, dtype: str
